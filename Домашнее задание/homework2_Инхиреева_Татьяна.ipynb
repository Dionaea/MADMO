# %% [markdown]
# ## Домашнее задание 2
# ### Линейные модели
# ---

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Задание 1 (Теоретическое)
# На лекции было сказано, что большие по модулю веса могут сигнализировать о наличии переобучения или о наличии линейной зависимости между признаками. В этом задании вам предстоит показать, что при отсутствии регуляризации (штрафа за большие веса) коэффициенты перед зависимыми признаками могут расти неограниченно.
#
# Рассмотрим данные, в которых истинная зависимость целевой переменной $y$ от признака $x$ описывается коэффициентом w (то есть истинная зависимость выглядит как $y = wx + ...$, где ... - другие признаки НЕ ЗАВИСЯЩИЕ от x). Искусственно добавим в модель зависимый признак равный -x.
# После обучения модели получим зависимость $y = w_1x + w_2 (-x) + ...$.
#
# Покажите, что веса $w_1$ и $w_2$ могут быть сколь угодно большими.

# %% [markdown]
# $y = w_1x + w_2 (-x) + ... = x(w_1 - w_2) + ... = x((w_1 + a) - (w_2 + a)) + ... $

# %% [markdown]
# К $w_1$ и $w_2$ можно добавить любое константное слагаемое. Оно не повлияет на результат и при этом может быть сколько угодно большим

# %% [markdown]
# #### Задание 2

# %% [markdown]
# Линейная регрессия с L2-регуляризацией или Ridge регрессия состоит в минимизации следующего функционала:
# $$||Y - Xw||^2 + \lambda ||w||^2 \rightarrow min$$
#
# Для данной задачи можно выписать явное решение:
# $$w = (X^TX + \lambda I)^{-1}X^TY$$

# %% [markdown]
# Реализуйте свой класс для гребневой регрессии, воспользовавшись формулой выше.

# %%
class MyRidgeRegression:
    
    def __init__(self, alpha=1.0):
        self.alpha = alpha
    
    def fit(self, X, y):
        # Принимает на вход X, y и вычисляет веса по данной выборке
        # Не забудьте про фиктивный признак равный 1!
        # Не применяйте регуляризацию к параметру b
        
        # ВАШ КОД ЗДЕСЬ
        a = np.ones((X.shape[0], 1))
        X = np.concatenate((X, a), axis=1)
        self.w = np.linalg.inv(X.T@X + self.alpha*np.eye(X.shape[1]))@X.T@y
        
    def predict(self, X):
        # Принимает на вход X и возвращает ответы модели
        # ВАШ КОД ЗДЕСЬ
        a = np.ones((X.shape[0], 1))
        X = np.concatenate((X, a), axis=1)
        y_pred = X@self.w
        return y_pred
    
    def get_weights(self):
        return self.w

# %% [markdown]
# Протестируем наш алгоритм на искусственных данных и сравним с линейной регрессией без регуляризации

# %%
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
linear_regr = LinearRegression()
ridge_regr = MyRidgeRegression(alpha=0.1)

linear_regr.fit(X_train, y_train)
ridge_regr.fit(X_train, y_train)

linear_regr_predictions = linear_regr.predict(X_test)
ridge_regr_predictions = ridge_regr.predict(X_test)

# %% [markdown]
# В качестве метрики качества воспользуемся MAE (средняя абсолютная ошибка)

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('Linear regression: ', mean_absolute_error(y_test, linear_regr_predictions))
# Out:
# Linear regression:  134.97450418682794

# %%
print('Ridge regression: ', mean_absolute_error(y_test, ridge_regr_predictions))
# Out:
# Ridge regression:  135.55934096901333

# %% [markdown]
# Попробуйте подобрать такой коэффициент регуляризации, чтобы ошибка на тесте была меньше, чем у модели без регуляризации.

# %%
mae = []

for alpha in [100, 10, 1, 0.1, 0.01, 0.001, 0.0001]:
    linear_regr = LinearRegression()
    ridge_regr = MyRidgeRegression(alpha=alpha)

    linear_regr.fit(X_train, y_train)
    ridge_regr.fit(X_train, y_train)

    linear_regr_predictions = linear_regr.predict(X_test)
    ridge_regr_predictions = ridge_regr.predict(X_test)

    mae.append((alpha, mean_absolute_error(y_test, ridge_regr_predictions)))

# %%
pd.DataFrame(mae, columns=['alpha', 'mae'])
# Out:
#       alpha         mae
# 0  100.0000  137.788721
# 1   10.0000  133.963268
# 2    1.0000  135.257576
# 3    0.1000  135.559341
# 4    0.0100  135.591255
# 5    0.0010  135.594465
# 6    0.0001  135.594786

# %% [markdown]
# При коэффициенте регуляризации 1 и меньше ошибка на тесте меньше, чем у модели без регуляризации

# %% [markdown]
# #### Задание 3
# В этом задании предлагается поиграться с различными ядрами SVM и подобрать лучшие параметры для каждого из них

# %% [markdown]
# Вам дан датасет (находится в файле banknote.data), в котором представлены различные статистики подсчитанные для изображения купюр. Задача состоит в классификации купюр на подлинные и фальшивые на основе этих данных.
# (Подробнее https://archive.ics.uci.edu/ml/datasets/banknote+authentication)

# %%
import seaborn as sns

# data = pd.read_csv('banknote.data', sep=',', header=-1)
data = pd.read_csv('https://datahub.io/machine-learning/banknote-authentication/r/banknote-authentication.csv')
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# одновременно нарисовать график и цветной и с распределениями не получается (особенность датасета)
sns.pairplot(data, diag_kind='', hue='Class')
sns.pairplot(data, diag_kind='kde')

data.head()
# Out:
#         V1      V2      V3       V4  Class
# 0  3.62160  8.6661 -2.8073 -0.44699      1
# 1  4.54590  8.1674 -2.4586 -1.46210      1
# 2  3.86600 -2.6383  1.9242  0.10645      1
# 3  3.45660  9.5228 -4.0112 -3.59440      1
# 4  0.32924 -4.4552  4.5718 -0.98880      1

# %% [markdown]
# Разделите выборку на трейн и тест в соотношении 1:1

# %%
# ВАШ КОД ЗДЕСЬ
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
from sklearn.svm import SVC

# %% [markdown]
# Для каждого из ядер svc (параметр kernel='linear', 'poly', 'rbf') постарайтесь подобрать наилучший набор параметров, который максимизирует метрику F1-score на тесте.
#
# НАПОМИНАНИЕ: $ F1 = 2\frac{precision \cdot recall}{precision + recall} $
#
# ПОДСКАЗКА: параметр C в SVC отвечает за коэффициент регуляризации, degree - степень полинома в полиномиальном ядре, gamma - коэффициент в экспоненте у гауссовского ядра. Про другие парамеры (если понадобятся) предлагается прочитать самостоятельно.

# %%
from sklearn.metrics import f1_score, make_scorer

# %%
from sklearn.model_selection import ParameterGrid

# %%
# ВАШ КОД ЗДЕСЬ
score = []
grid = ParameterGrid([{'kernel': ['linear'], 'C':[0.1, 0.25, 0.5, 0.75, 1, 10]}, 
                      {'kernel': ['rbf'], 'gamma': [0.1, 1, 10, 100], 'C':[0.1, 0.25, 0.5, 0.75, 1, 10]},
                      {'kernel': ['poly'], 'degree': [2, 3, 4, 5], 'C':[0.1, 0.25, 0.5, 0.75, 1, 10]}])
for params in grid:
    svc = SVC(**params)
    svc.fit(X_train, y_train)
    y_pred = svc.predict(X_test)
    score.append((params, f1_score(y_test, y_pred)))

# %%
score_df = pd.DataFrame(score, columns=['params', 'f1'])
score_df.sort_values('f1', ascending=False)
# Out:
#                                         params        f1
# 14   {'C': 0.5, 'gamma': 0.1, 'kernel': 'rbf'}  1.000000
# 10  {'C': 0.25, 'gamma': 0.1, 'kernel': 'rbf'}  1.000000
# 27      {'C': 10, 'gamma': 1, 'kernel': 'rbf'}  0.998658
# 23       {'C': 1, 'gamma': 1, 'kernel': 'rbf'}  0.998658
# 19    {'C': 0.75, 'gamma': 1, 'kernel': 'rbf'}  0.998658
# 26    {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}  0.998654
# 22     {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}  0.998654
# 18  {'C': 0.75, 'gamma': 0.1, 'kernel': 'rbf'}  0.998654
# 15     {'C': 0.5, 'gamma': 1, 'kernel': 'rbf'}  0.997319
# 6    {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}  0.995951
# 5                {'C': 10, 'kernel': 'linear'}  0.991957
# 2               {'C': 0.5, 'kernel': 'linear'}  0.991892
# 1              {'C': 0.25, 'kernel': 'linear'}  0.990553
# 3              {'C': 0.75, 'kernel': 'linear'}  0.989218
# 0               {'C': 0.1, 'kernel': 'linear'}  0.989130
# 4                 {'C': 1, 'kernel': 'linear'}  0.987887
# 51    {'C': 10, 'degree': 3, 'kernel': 'poly'}  0.985034
# 50    {'C': 10, 'degree': 2, 'kernel': 'poly'}  0.983607
# 11    {'C': 0.25, 'gamma': 1, 'kernel': 'rbf'}  0.978947
# 36  {'C': 0.25, 'degree': 4, 'kernel': 'poly'}  0.976064
# 47     {'C': 1, 'degree': 3, 'kernel': 'poly'}  0.972376
# 46     {'C': 1, 'degree': 2, 'kernel': 'poly'}  0.966667
# 43  {'C': 0.75, 'degree': 3, 'kernel': 'poly'}  0.966667
# 42  {'C': 0.75, 'degree': 2, 'kernel': 'poly'}  0.966667
# 52    {'C': 10, 'degree': 4, 'kernel': 'poly'}  0.965229
# 38   {'C': 0.5, 'degree': 2, 'kernel': 'poly'}  0.957983
# 39   {'C': 0.5, 'degree': 3, 'kernel': 'poly'}  0.956522
# 31   {'C': 0.1, 'degree': 3, 'kernel': 'poly'}  0.955307
# 30   {'C': 0.1, 'degree': 2, 'kernel': 'poly'}  0.955056
# 34  {'C': 0.25, 'degree': 2, 'kernel': 'poly'}  0.950635
# 53    {'C': 10, 'degree': 5, 'kernel': 'poly'}  0.937322
# 35  {'C': 0.25, 'degree': 3, 'kernel': 'poly'}  0.932568
# 40   {'C': 0.5, 'degree': 4, 'kernel': 'poly'}  0.905882
# 44  {'C': 0.75, 'degree': 4, 'kernel': 'poly'}  0.881203
# 48     {'C': 1, 'degree': 4, 'kernel': 'poly'}  0.874433
# 41   {'C': 0.5, 'degree': 5, 'kernel': 'poly'}  0.865854
# 37  {'C': 0.25, 'degree': 5, 'kernel': 'poly'}  0.851508
# 28     {'C': 10, 'gamma': 10, 'kernel': 'rbf'}  0.846416
# 49     {'C': 1, 'degree': 5, 'kernel': 'poly'}  0.841121
# 45  {'C': 0.75, 'degree': 5, 'kernel': 'poly'}  0.837500
# 24      {'C': 1, 'gamma': 10, 'kernel': 'rbf'}  0.826667
# 32   {'C': 0.1, 'degree': 4, 'kernel': 'poly'}  0.801296
# 33   {'C': 0.1, 'degree': 5, 'kernel': 'poly'}  0.794433
# 20   {'C': 0.75, 'gamma': 10, 'kernel': 'rbf'}  0.776618
# 7      {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}  0.732283
# 16    {'C': 0.5, 'gamma': 10, 'kernel': 'rbf'}  0.716763
# 29    {'C': 10, 'gamma': 100, 'kernel': 'rbf'}  0.710602
# 25     {'C': 1, 'gamma': 100, 'kernel': 'rbf'}  0.707897
# 21  {'C': 0.75, 'gamma': 100, 'kernel': 'rbf'}  0.704545
# 9    {'C': 0.1, 'gamma': 100, 'kernel': 'rbf'}  0.703214
# 8     {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}  0.703214
# 12   {'C': 0.25, 'gamma': 10, 'kernel': 'rbf'}  0.703214
# 17   {'C': 0.5, 'gamma': 100, 'kernel': 'rbf'}  0.703214
# 13  {'C': 0.25, 'gamma': 100, 'kernel': 'rbf'}  0.703214

# %% [markdown]
# #### БОНУС

# %% [markdown]
# Предлагаю немного расслабиться и посмотреть как делается полиномиальная регрессия (добавление степенных признаков в модель) и как Lasso проводит отбор признаков.

# %%
# Data generation

def gen_batch(n, w, beta):
    d = len(w)
    X = np.random.uniform(-10, 10, (n, 1))
    X = np.sort(X, axis=0)
    X = np.hstack([X ** i for i in range(d)])
    t = X.dot(w) + np.random.normal(size=n) / beta ** 0.5
    return X, t

n = 200
d = 21
w_true = np.zeros(d)
w_true[1] = 100
w_true[3] = -1
beta_true = 1e-4

X_train, t_train = gen_batch(n, w_true, beta_true)
X_test, t_test = gen_batch(n, w_true, beta_true)

# Visualization
plt.figure(figsize=(10, 5))
plt.scatter(X_train[:, 1], t_train, s=3, label='Train data', alpha=0.3)
plt.scatter(X_test[:, 1], t_test, s=3, label='Test data', alpha=0.3)
plt.plot(X_train[:, 1], X_train.dot(w_true), label='Ground truth')

plt.axes().set_xlabel('x')
plt.axes().set_ylabel('y')
plt.legend(ncol=3, loc=9, bbox_to_anchor=(0.5, 1.15))
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\Anaconda\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# Ridge Regression with Cross-Validation
from sklearn.linear_model import RidgeCV
ridge = RidgeCV(cv=20, alphas=10.**np.arange(-6, 3, 1),
                fit_intercept=False)
ridge.fit(X_train, t_train)
w_ridge = ridge.coef_

# %%
# Lasso Regression with Cross-Validation
from sklearn.linear_model import LassoCV, Lasso
lasso = LassoCV(cv=20, alphas=10.**np.arange(-6, 3, 1),
                fit_intercept=False)
lasso.fit(X_train, t_train)
w_lasso = lasso.coef_
# Out:
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2022697.149967824, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1191135.9462575857, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1027997.6013208425, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1007629.744406778, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1005024.8751929675, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1004371.4337891913, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1004018.1885177998, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1003772.5839015142, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1003593.2682747561, tolerance: 1707.045579610936
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2020556.9967328655, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1173233.7773508737, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1009327.1301120443, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 985604.0981001636, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 981973.8746547604, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 981086.6519172535, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 980707.9808001122, tolerance: 1638.5899088733966
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap:
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1194798.7944685477, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1032211.9122595125, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1010006.6985542708, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006969.758381576, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006336.0266988981, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006095.9286858754, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1005956.8486328985, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1005856.936232831, tolerance: 1579.61524711371
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2027156.46499555, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1173659.3338315836, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1008089.3846825665, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 985265.3243616224, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 982098.2762777983, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 981414.924757309, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 981136.8370232177, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 980970.658213621, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 980855.9894124349, tolerance: 1623.9138770857924
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2036246.3726038234, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1179995.0484798332, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1017481.4589433174, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 995186.154656984, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 992089.3288741488, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 991424.0063680593, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 991164.1195337379, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 991011.3490669569, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 990901.415568064, tolerance: 1638.9375733934435
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1957979.4521656753, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1190378.9379145189, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1029484.9140266544, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1009357.7208132093, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1007186.0149915426, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006860.6015116455, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006718.2013127444, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006592.7776027746, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006468.8602069651, tolerance: 1691.7104993962348
#   tol, rng, random, positive)
# D:\Anaconda\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1259506.1117835608, tolerance: 1727.6412622881235
#   positive)

# %%
def l2_error(X, t, w):
    return np.sum((X.dot(w.ravel()) - t) ** 2)

# Comparison
print('Ridge Regression')
print('Features remaining:', np.sum(np.abs(w_ridge) > 1e-15), '/', d)
print('Train error:', l2_error(X_train, t_train, w_ridge) / n)
print('Test error: ', l2_error(X_test, t_test, w_ridge) / n)
print('-'*50)
print('Lasso Regression')
print('Features remaining:', np.sum(np.abs(w_lasso) > 1e-15), '/', d)
print('Train error:', l2_error(X_train, t_train, w_lasso) / n)
print('Test error: ', l2_error(X_test, t_test, w_lasso) / n)

plt.figure(figsize=(10, 5))
plt.scatter(X_train[:, 1], t_train, s=3, label='Train data', alpha=0.3)
plt.scatter(X_test[:, 1], t_test, s=3, label='Test data', alpha=0.3)
plt.plot(X_train[:, 1], X_train.dot(w_true), label='Ground truth')
plt.plot(X_train[:, 1], X_train.dot(w_ridge), label='Ridge')
plt.plot(X_train[:, 1], X_train.dot(w_lasso), label='Lasso')

plt.axes().set_xlabel('x')
plt.axes().set_ylabel('y')
plt.legend(ncol=3, loc=9, bbox_to_anchor=(0.5, 1.25))
plt.show()
# Out:
# Ridge Regression
# Features remaining: 21 / 21
# Train error: 10232.91054457314
# Test error:  9541.429245126785
# --------------------------------------------------
# Lasso Regression
# Features remaining: 16 / 21
# Train error: 10629.935786374139
# Test error:  9495.03242251985
# D:\Anaconda\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# D:\Anaconda\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
